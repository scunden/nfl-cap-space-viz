# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import string
import scraper
import re
import pickle

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open('data/player_details.pickle', 'rb') as handle:
    player_details = pickle.load(handle)

with open('data/team_details_22.pickle', 'rb') as handle:
    team_details_22 = pickle.load(handle)

with open('data/team_details_23.pickle', 'rb') as handle:
    team_details_23 = pickle.load(handle)

# %%
player_details, team_details_22, team_details_23 = scraper.scrape_data()
# Out:
# 11/29/2022 05:12:43 PM Starting new HTTPS connection (1): www.spotrac.com:443
# 11/29/2022 05:12:44 PM https://www.spotrac.com:443 "GET /nfl/ HTTP/1.1" 200 None
# 11/29/2022 05:12:44 PM Scraping team URLs...
# 11/29/2022 05:12:44 PM Appending https://www.spotrac.com/nfl/arizona-cardinals/cap/
# 11/29/2022 05:12:44 PM Appending https://www.spotrac.com/nfl/atlanta-falcons/cap/
# 11/29/2022 05:12:44 PM Appending https://www.spotrac.com/nfl/baltimore-ravens/cap/
# 11/29/2022 05:12:44 PM Appending https://www.spotrac.com/nfl/buffalo-bills/cap/
# 11/29/2022 05:12:44 PM Appending https://www.spotrac.com/nfl/carolina-panthers/cap/
# 11/29/2022 05:12:44 PM Appending https://www.spotrac.com/nfl/chicago-bears/cap/
# 11/29/2022 05:12:44 PM Appending https://www.spotrac.com/nfl/cincinnati-bengals/cap/
# 11/29/2022 05:12:44 PM Appending https://www.spotrac.com/nfl/cleveland-browns/cap/
# 11/29/2022 05:12:44 PM Appending https://www.spotrac.com/nfl/dallas-cowboys/cap/
# ...

# %%
player_details
# Out:
#            Player Name Position Level 3  Base Salary Signing Bonus  \
# 0            T.J. Watt              OLB  $15,000,000    $7,118,694
# 1      Cameron Heyward               DE   $6,500,000    $4,050,000
# 2   Minkah Fitzpatrick                S   $4,000,000    $3,500,000
# 3       Larry Ogunjobi               DT   $1,535,000    $6,465,000
# 4      Diontae Johnson               WR   $1,500,000    $6,116,690
# ..                 ...              ...          ...           ...
# 29       Samuel Womack               CB     $870,000       $70,831
# 30         Nick Zakelj                T     $870,000       $47,589
# 31         Kalia Davis               DT     $870,000       $33,004
# 32         Brock Purdy               QB     $870,000       $19,252
# 33        Jordan Mason               RB     $870,000        $3,333
#
#    Roster Bonus Option Bonus Workout Bonus Restruc. Bonus Misc.  \
# 0             -            -             -     $2,250,000     -
# ...
